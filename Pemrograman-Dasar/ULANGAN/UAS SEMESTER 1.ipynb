# %%
import random

tebak = int(random.randint(1,10))
i = 1

while i <= 4:
  x = int(input())
  i = i + 1
  if tebak == x:
    print ("Anda Menang")
    break
  else:
    if i == 5:
      print ("Maaf anda kalah")
    else:
      print ("Coba lagi")
