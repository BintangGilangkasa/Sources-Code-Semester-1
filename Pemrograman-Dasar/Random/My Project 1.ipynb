# %%
print ("========================================================================================")
print ("\n\n\tAssalamualaikum wr.wb")
print ("\nWelcome to My drive this, semoga program yang saya buat menambah ilmu buat saya")
print ("\nNama  : Bintang Gilangkasa Syailendra \nNIM   : 23090230002 \nProdi : Sains Data")
print ("\nSelamat mengoreksi Tugas Saya Pak, Kesepian tanpa kekasih cukup sekian Terima kasih:)")
print ("\n\tWassalamualaikum wr.wb.")
print ("\n\n========================================================================================")
# Out:
# ========================================================================================
#
#
# 	Assalamualaikum wr.wb
#
# Welcome to My drive this, semoga program yang saya buat menambah ilmu buat saya
#
# Nama  : Bintang Gilangkasa Syailendra
# NIM   : 23090230002
# Prodi : Sains Data
#
# Selamat mengoreksi Tugas Saya Pak, Kesepian tanpa kekasih cukup sekian Terima kasih:)
#
# 	Wassalamualaikum wr.wb.
#
#
# ========================================================================================

# %%
if True:
 print ("saya masih belajar python")
# Out:
# saya masih belajar python

# %% [markdown]
# # Materi 1

# %%
if True:
    print ("how to become a programer")
# Out:
# how to become a programer

# %%
# if 10 > 5:
 print ("maka 10 lebih besar dari 5")
if 10 < 25:
 print ("maka 10 lebih kurang dari 25")

# %%
print ("Bintang")
print ("Gilangkasa Syailendra")
# Out:
# Bintang
# Gilangkasa Syailendra

# %%
"""
Ini adalah komentar
ditulis dalam
lebih dari satu baris
"""
print("Hello, World")
# Out:
# Hello, World

# %%
# Ini adalah komentar
print("Ini bukan komentar")
# Out:
# Ini bukan komentar

# %%
"""
komentar ini
hanya bisa dibuat
oleh prodi Sains Data
"""
print ("I want a money")
# Out:
# I want a money

# %%
print (10+8)
print (45-15)
print (12/4)
print (12//4)
print (14*4)
print (11**2)
# Out:
# 18
# 30
# 3.0
# 3
# 56
# 121

# %%
print (24+13*2)
# Out:
# 50

# %%
age = 35
if age > 18:
 print ("sudah cukup umur")
if age < 17:
 print ("belum cukup umur")
# Out:
# sudah cukup umur

# %%
print ("SECURITY LOGIN")
username = input("username : ")
password = input("password : ")

if username == ("Bintang"):
 print ("\nBIODATA \n\nNama    : Bintang Gilangkasa Syailendra \nNIM     : 23090230002 \nJurusan : Data Science")
elif username == ("Gosh"):
 print ("Hey there Gosh!")
else :
  print ("Go away!")

if password == ("12345"):
 print ("")
elif password == ("Gosh"):
 print ("Hey there Gosh!")
else :
  print ("Go away!")
# Out:
#   File "<ipython-input-2-36191bc8ba7a>", line 19
#     if password ("false")
#                          ^
# SyntaxError: expected ':'

# %%
def salam(nama):
    print ("assalamualaikum" + nama)
salam(bintang)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-b26abc8ce90b> in <cell line: 3>()
#       1 def salam(nama):
#       2     print ("assalamualaikum" + nama)
# ----> 3 salam(bintang)
#
# NameError: name 'bintang' is not defined

# %% [markdown]
# # Materi 2

# %%
print ("Hello Bintang!")
# Out:
# Hello Bintang!

# %%
x = 5
print (x)
print (x*5)
# Out:
# 5
# 25
